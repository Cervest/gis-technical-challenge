# %%
import glob

import xarray

# %%
# Download from S3 - specify path here.

NC_FILE_PATH   = "<path_to_files>/netcdf4/"
ZARR_FILE_PATH = "<path_to_files>/zarr/"

# %%
# %time xarr = xarray.open_mfdataset(NC_FILE_PATH, combine='by_coords').load()
# Out:
# CPU times: user 3min 18s, sys: 13.9 s, total: 3min 31s
# Wall time: 3min 45s

# %% [markdown]
# ## Generating zarr files
#
# Initally, we needed to generate the files in a zarr format. `xarray` can currently only read zarr files which it has itself written, using:
#
# ```python
# xarr.to_zarr(ZARR_FILE_PATH, consolidated=True)
# ```
#
# Since the files are already contained in the S3 bucket, we can go ahead and use those directly.

# %%
# %time xarray.open_zarr(ZARR_FILE_PATH).load()
# Out:
# CPU times: user 45.4 s, sys: 6.69 s, total: 52.1 s
# Wall time: 17.4 s
# <xarray.Dataset>
# Dimensions:    (latitude: 169, level: 1, longitude: 293, time: 87600)
# Coordinates:
#   * latitude   (latitude) float64 74.0 73.75 73.5 73.25 ... 32.5 32.25 32.0
#   * level      (level) float64 1e+03
#   * longitude  (longitude) float64 333.0 333.2 333.5 333.8 ... 45.5 45.75 46.0
#   * time       (time) datetime64[ns] 1979-01-01 ... 1989-01-02T23:00:00
# Data variables:
#     R          (time, level, latitude, longitude) float32 44.83952 ... 83.39159
# Attributes:
#     CONVERSION_DATE:      Mon May 13 18:31:49 MDT 2019
#     CONVERSION_PLATFORM:  Linux casper13 3.10.0-693.21.1.el7.x86_64 #1 SMP We...
#     Conventions:          CF-1.6
#     DATA_SOURCE:          ECMWF: https://cds.climate.copernicus.eu, Copernicu...
#     NCO:                  netCDF Operators version 4.7.9 (Homepage = http://n...
#     NETCDF_COMPRESSION:   NCO: Precision-preserving compression to netCDF4/HD...
#     NETCDF_CONVERSION:    CISL RDA: Conversion from ECMWF GRIB 1 data to netC...
#     NETCDF_VERSION:       4.6.1
#     history:              Mon Mar 30 02:31:12 2020: ncks -d latitude,32.0,74....

# %% [markdown]
# ## `dask.distributed`
#
# The above reading took ~ 50s. We can improve this by creating a local dask cluster, to which `xarray` then delegates scheduling the tasks for reading files from disk.
#
# This has the advatanges of being faster and very easily scalable. Were we to run this across multiple nodes in a cloud-based cluster, we'd need only specify a different scheduler - the API is otherwise unchanged.

# %%
from dask.distributed import Client, LocalCluster

cluster = LocalCluster()  # Defaults to 16 workers
client = Client(cluster)

xarr = xarray.open_zarr("/home/tom/tmp/relative-humidity-data/zarr", consolidated=True)

# %%
# %%prun -q -T prun_output.txt

loaded_xarr = xarr.load()
# Out:
#
# *** Profile printout saved to text file 'prun_output.txt'.

# %% [markdown]
# ## Profiling
#
# This takes anywhere from 30 - 40s on our machines (usually depending on what other activity is present).
#
# We can see below that a lot of this time is spend by various threads awaiting access to some lock.

# %%
print(open("prun_output.txt").read())
# Out:
#          671327 function calls (537788 primitive calls) in 37.911 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        12   24.890    2.074   24.890    2.074 {method 'acquire' of '_thread.lock' objects}
#         1   10.846   10.846   10.891   10.891 core.py:4318(concatenate3)
#         1    1.235    1.235   37.911   37.911 dataset.py:625(load)
#      4098    0.122    0.000    0.134    0.000 base_events.py:738(_call_soon)
#         5    0.105    0.021    0.108    0.022 core.py:263(reverse_dict)
#     36868    0.077    0.000    0.077    0.000 utils.py:751(tokey)
# 36866/4097    0.045    0.000    0.071    0.000 utils_comm.py:166(unpack_remotedata)
#      8197    0.044    0.000    0.048    0.000 core.py:159(get_dependencies)
#      4097    0.043    0.000    0.043    0.000 {built-in method _pickle.dumps}
# 91274/28679    0.042    0.000    0.051    0.000 core.py:234(flatten)
#         2    0.033    0.017    0.059    0.029 {built-in method builtins.sorted}
#      4098    0.030    0.000    0.030    0.000 {method 'send' of '_socket.socket' objects}
# 12289/4097    0.028    0.000    0.043    0.000 utils.py:790(convert)
# 36864/16384    0.021    0.000    0.056    0.000 utils_comm.py:226(<genexpr>)
#     28683    0.015    0.000    0.018    0.000 core.py:26(istask)
#      4096    0.015    0.000    0.036    0.000 client.py:161(__init__)
#     43788    0.015    0.000    0.015    0.000 order.py:544(__lt__)
#     48468    0.014    0.000    0.017    0.000 {built-in method builtins.isinstance}
#      4098    0.013    0.000    0.192    0.000 asyncio.py:171(add_callback)
#      4097    0.012    0.000    0.101    0.000 worker.py:3300(dumps_task)
#      8192    0.010    0.000    0.215    0.000 client.py:345(release)
#      4096    0.009    0.000    0.011    0.000 order.py:154(dependents_key)
#         1    0.008    0.008    0.013    0.013 optimization.py:417(fuse)
#      4097    0.008    0.000    0.052    0.000 pickle.py:26(dumps)
#         1    0.008    0.008    0.015    0.015 order.py:482(ndependencies)
#         9    0.007    0.001    0.118    0.013 {method 'update' of 'dict' objects}
#      4096    0.007    0.000    0.008    0.000 client.py:1134(_inc_ref)
#      4098    0.007    0.000    0.178    0.000 base_events.py:762(call_soon_threadsafe)
#         1    0.007    0.007    0.019    0.019 client.py:2518(<dictcomp>)
#      4098    0.007    0.000    0.010    0.000 events.py:32(__init__)
#      8192    0.007    0.000    0.011    0.000 utils.py:779(_maybe_complex)
#         1    0.007    0.007    0.007    0.007 optimization.py:111(optimize_slices)
#     12288    0.006    0.000    0.028    0.000 utils.py:796(<genexpr>)
#      4098    0.006    0.000    0.037    0.000 selector_events.py:129(_write_to_self)
#      4096    0.006    0.000    0.014    0.000 worker.py:3285(dumps_function)
#      4096    0.006    0.000    0.008    0.000 utils.py:1496(__getitem__)
#         1    0.006    0.006    0.007    0.007 order.py:355(graph_metrics)
#         1    0.005    0.005   25.585   25.585 client.py:2564(get)
#         1    0.005    0.005    0.060    0.060 utils.py:806(<dictcomp>)
#         1    0.005    0.005    0.041    0.041 client.py:2544(<dictcomp>)
#     36872    0.005    0.000    0.005    0.000 {built-in method builtins.callable}
#         1    0.005    0.005    0.019    0.019 client.py:2533(<dictcomp>)
#      4096    0.005    0.000    0.057    0.000 worker.py:3334(warn_dumps)
#    4385/1    0.005    0.000    0.011    0.011 utils.py:227(concrete)
#         1    0.005    0.005    0.105    0.105 optimization.py:73(hold_keys)
# 33392/33390    0.004    0.000    0.004    0.000 {built-in method builtins.len}
#    4386/1    0.004    0.000    0.006    0.006 utils_comm.py:248(pack_data)
#      4097    0.004    0.000    0.014    0.000 {built-in method builtins.any}
#         1    0.003    0.003    0.074    0.074 client.py:2501(<dictcomp>)
#     24578    0.003    0.000    0.003    0.000 {built-in method builtins.issubclass}
#         1    0.003    0.003    0.025    0.025 client.py:2527(<dictcomp>)
#         1    0.003    0.003    0.461    0.461 client.py:2463(_graph_to_futures)
#      4097    0.003    0.000    0.004    0.000 client.py:2534(<listcomp>)
#      4097    0.003    0.000    0.004    0.000 {built-in method builtins.sum}
#         1    0.003    0.003    0.036    0.036 optimization.py:18(cull)
#         2    0.003    0.001    0.028    0.014 optimization.py:49(<listcomp>)
#         1    0.003    0.003    0.005    0.005 optimization.py:331(<listcomp>)
#     20614    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#         1    0.002    0.002   36.675   36.675 base.py:382(compute)
#         3    0.002    0.001    0.011    0.004 {built-in method builtins.max}
#       256    0.002    0.000    0.002    0.000 core.py:1084(<listcomp>)
#     12300    0.002    0.000    0.002    0.000 {method 'add' of 'set' objects}
#     290/1    0.002    0.000    0.006    0.006 utils_comm.py:276(<listcomp>)
#         1    0.002    0.002    0.187    0.187 optimization.py:23(optimize)
#      4098    0.002    0.000    0.002    0.000 {built-in method _contextvars.copy_context}
#      4099    0.002    0.000    0.002    0.000 {built-in method builtins.hasattr}
#      4096    0.002    0.000    0.003    0.000 client.py:371(__del__)
#      4097    0.002    0.000    0.002    0.000 client.py:2519(<setcomp>)
#       372    0.002    0.000    0.003    0.000 utils_perf.py:183(_gc_callback)
#      4096    0.002    0.000    0.002    0.000 __init__.py:998(__getitem__)
#      4096    0.002    0.000    0.002    0.000 client.py:417(__init__)
#         1    0.002    0.002    0.002    0.002 core.py:168(slices_from_chunks)
#         1    0.002    0.002    0.002    0.002 optimization.py:83(<setcomp>)
#      4390    0.002    0.000    0.002    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.002    0.002    0.002    0.002 blockwise.py:555(<setcomp>)
#         1    0.002    0.002    0.002    0.002 order.py:270(<setcomp>)
#         1    0.001    0.001    0.002    0.002 order.py:501(<dictcomp>)
#         1    0.001    0.001    0.002    0.002 client.py:2493(<dictcomp>)
#      8192    0.001    0.000    0.001    0.000 order.py:514(<genexpr>)
#      4096    0.001    0.000    0.002    0.000 core.py:4347(<lambda>)
#      4390    0.001    0.000    0.003    0.000 abc.py:96(__instancecheck__)
#         1    0.001    0.001    0.001    0.001 optimization.py:61(<dictcomp>)
#      4097    0.001    0.000    0.001    0.000 order.py:467(<genexpr>)
#         1    0.001    0.001    0.089    0.089 order.py:82(order)
#      4098    0.001    0.000    0.001    0.000 base_events.py:506(_check_closed)
#         1    0.001    0.001    0.001    0.001 client.py:2505(<dictcomp>)
#      4098    0.001    0.000    0.001    0.000 base_events.py:1877(get_debug)
#      4099    0.001    0.000    0.001    0.000 {built-in method _thread.get_ident}
#         4    0.001    0.000    0.001    0.000 {built-in method io.open}
#      4097    0.001    0.000    0.001    0.000 order.py:541(__init__)
#      4096    0.001    0.000    0.001    0.000 client.py:597(<lambda>)
#         1    0.001    0.001    0.001    0.001 client.py:2504(<dictcomp>)
#      4127    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      4105    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#     289/1    0.001    0.000    0.003    0.003 core.py:1079(keys)
#         2    0.001    0.000    0.001    0.000 {built-in method posix.urandom}
#         1    0.001    0.001   37.911   37.911 <string>:1(<module>)
#      4095    0.001    0.000    0.001    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#      4103    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.001    0.001 dicttoolz.py:18(merge)
#         1    0.000    0.000    0.011    0.011 optimization.py:290(inline_functions)
#      33/1    0.000    0.000    0.003    0.003 core.py:1086(<listcomp>)
#         1    0.000    0.000    0.000    0.000 client.py:2502(<listcomp>)
#         1    0.000    0.000    0.187    0.187 base.py:220(<listcomp>)
#         1    0.000    0.000    0.000    0.000 order.py:428(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 order.py:144(<genexpr>)
#         1    0.000    0.000    0.000    0.000 order.py:506(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         4    0.000    0.000    0.001    0.000 _pslinux.py:1737(memory_info)
#      27/5    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         5    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000   10.891   10.891 core.py:981(finalize)
#         3    0.000    0.000   24.890    8.297 threading.py:270(wait)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:493(_parse)
#    120/50    0.000    0.000    0.000    0.000 core.py:4154(deepfirst)
#         8    0.000    0.000    0.000    0.000 slicing.py:1214(cached_cumsum)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:71(_compile)
#         4    0.000    0.000    0.001    0.000 _common.py:445(wrapper)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         1    0.000    0.000   24.890   24.890 utils.py:300(sync)
#         1    0.000    0.000   37.911   37.911 {built-in method builtins.exec}
#         1    0.000    0.000    0.192    0.192 base.py:204(collections_to_dsk)
#         4    0.000    0.000    0.000    0.000 _pslinux.py:1752(<listcomp>)
#         4    0.000    0.000    0.000    0.000 core.py:4148(<listcomp>)
#         3    0.000    0.000   24.890    8.297 threading.py:540(wait)
#         9    0.000    0.000    0.000    0.000 config.py:432(get)
#       2/1    0.000    0.000    0.000    0.000 base.py:985(get_scheduler)
#         1    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 variable.py:165(as_compatible_data)
#        30    0.000    0.000    0.000    0.000 sre_parse.py:233(__next)
#        49    0.000    0.000    0.000    0.000 core.py:4141(shape)
#         3    0.000    0.000    0.000    0.000 typing.py:865(__new__)
#         3    0.000    0.000    0.000    0.000 dataset.py:563(variables)
#       8/4    0.000    0.000    0.000    0.000 core.py:86(_execute_task)
#         1    0.000    0.000    0.000    0.000 core.py:325(_toposort)
#         2    0.000    0.000    0.000    0.000 uuid.py:130(__init__)
#         1    0.000    0.000   24.890   24.890 client.py:768(sync)
#        57    0.000    0.000    0.000    0.000 itertoolz.py:31(accumulate)
#         1    0.000    0.000    0.002    0.002 blockwise.py:554(_optimize_blockwise)
#         1    0.000    0.000    0.003    0.003 base.py:229(_extract_graph_and_keys)
#         4    0.000    0.000    0.001    0.000 _pslinux.py:1513(wrapper)
#         2    0.000    0.000    0.000    0.000 utils_perf.py:88(_add_measurement)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         4    0.000    0.000    0.000    0.000 slicing.py:1204(_cumsum)
#         4    0.000    0.000    0.001    0.000 __init__.py:1061(memory_info)
#         4    0.000    0.000    0.000    0.000 core.py:181(<listcomp>)
#        29    0.000    0.000    0.000    0.000 sre_parse.py:254(get)
#         1    0.000    0.000    0.002    0.002 blockwise.py:506(optimize_blockwise)
#         1    0.000    0.000    0.000    0.000 re.py:287(_compile)
#         2    0.000    0.000    0.000    0.000 utils.py:475(dispatch)
#        21    0.000    0.000    0.000    0.000 config.py:41(canonical_name)
#         1    0.000    0.000    0.000    0.000 base.py:647(tokenize)
#        29    0.000    0.000    0.000    0.000 sre_parse.py:172(append)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:174(getwidth)
#         1    0.000    0.000   24.890   24.890 client.py:1874(gather)
#      27/5    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 worker.py:3047(get_client)
#         1    0.000    0.000    0.000    0.000 client.py:96(_get_global_client)
#        29    0.000    0.000    0.000    0.000 sre_parse.py:164(__getitem__)
#         1    0.000    0.000    0.000    0.000 worker.py:3020(get_worker)
#         1    0.000    0.000    0.000    0.000 core.py:4118(chunks_from_arrays)
#         1    0.000    0.000    0.001    0.001 base.py:245(unpack_collections)
#         4    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#         2    0.000    0.000    0.000    0.000 utils.py:388(__iter__)
#         4    0.000    0.000    0.000    0.000 {built-in method time.thread_time}
#         3    0.000    0.000    0.000    0.000 threading.py:258(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:222(__init__)
#         4    0.000    0.000    0.000    0.000 metrics.py:88(_native_thread_time)
#         4    0.000    0.000    0.001    0.000 _common.py:712(open_binary)
#         2    0.000    0.000    0.000    0.000 utils.py:1024(ensure_dict)
#         2    0.000    0.000    0.001    0.000 uuid.py:778(uuid4)
#        12    0.000    0.000    0.000    0.000 _collections_abc.py:742(__iter__)
#         1    0.000    0.000    0.000    0.000 core.py:1159(shape)
#         1    0.000    0.000    0.000    0.000 warnings.py:130(filterwarnings)
#         2    0.000    0.000    0.000    0.000 utils_perf.py:115(start_timing)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:759(compile)
#         1    0.000    0.000    0.000    0.000 base.py:318(repack)
#         2    0.000    0.000    0.003    0.002 core.py:1073(__dask_keys__)
#         1    0.000    0.000    0.000    0.000 _asarray.py:16(asarray)
#         3    0.000    0.000    0.000    0.000 threading.py:249(__exit__)
#         2    0.000    0.000    0.000    0.000 utils_perf.py:119(stop_timing)
#         1    0.000    0.000    0.000    0.000 itertoolz.py:72(groupby)
#         1    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#         1    0.000    0.000    0.000    0.000 dataset.py:645(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:389(parent)
#         1    0.000    0.000    0.000    0.000 functools.py:33(update_wrapper)
#         1    0.000    0.000    0.000    0.000 core.py:130(get)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:536(_compile_info)
#         1    0.000    0.000    0.000    0.000 variable.py:340(data)
#        49    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#         1    0.000    0.000   10.891   10.891 base.py:438(<listcomp>)
#         4    0.000    0.000    0.000    0.000 core.py:8(ishashable)
#         1    0.000    0.000    0.000    0.000 highlevelgraph.py:174(merge)
#       5/1    0.000    0.000    0.000    0.000 utils.py:1379(ndimlist)
#        29    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55df59b68fc0}
#         8    0.000    0.000    0.000    0.000 slicing.py:1187(__init__)
#         5    0.000    0.000    0.000    0.000 core.py:1161(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {method 'split' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 core.py:459(quote)
#        12    0.000    0.000    0.000    0.000 _collections_abc.py:271(__subclasshook__)
#         1    0.000    0.000    0.012    0.012 dicttoolz.py:87(keymap)
#         1    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:937(parse)
#         4    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#         1    0.000    0.000    0.000    0.000 blockwise.py:846(fuse_roots)
#         1    0.000    0.000    0.000    0.000 base.py:278(_unpack)
#         3    0.000    0.000    0.000    0.000 weakref.py:213(keys)
#         9    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:505(__init__)
#        31    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         1    0.000    0.000    0.000    0.000 client.py:918(_send_to_scheduler)
#         1    0.000    0.000    0.000    0.000 core.py:180(<listcomp>)
#         1    0.000    0.000    0.000    0.000 order.py:123(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 gen.py:156(coroutine)
#        17    0.000    0.000    0.000    0.000 core.py:4350(<genexpr>)
#         1    0.000    0.000    0.105    0.105 dicttoolz.py:71(valmap)
#         4    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         3    0.000    0.000    0.000    0.000 threading.py:246(__enter__)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:435(_parse_sub)
#         1    0.000    0.000    0.000    0.000 utils.py:501(__call__)
#        11    0.000    0.000    0.000    0.000 utils.py:385(__getitem__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:676(items)
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         1    0.000    0.000    0.000    0.000 core.py:394(toposort)
#         8    0.000    0.000    0.000    0.000 slicing.py:1200(__hash__)
#         3    0.000    0.000    0.000    0.000 threading.py:261(_is_owned)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:461(_get_literal_prefix)
#        27    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_tolower}
#         1    0.000    0.000    0.000    0.000 enum.py:828(__and__)
#         1    0.000    0.000    0.000    0.000 variable.py:316(shape)
#         3    0.000    0.000    0.000    0.000 threading.py:255(_release_save)
#         2    0.000    0.000    0.000    0.000 uuid.py:325(hex)
#         1    0.000    0.000    0.000    0.000 {built-in method math.log}
#         1    0.000    0.000    0.000    0.000 sre_parse.py:224(__init__)
#         2    0.000    0.000    0.000    0.000 enum.py:278(__call__)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:598(_code)
#         1    0.000    0.000    0.000    0.000 core.py:179(<listcomp>)
#         5    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 core.py:347(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:435(<listcomp>)
#         1    0.000    0.000    0.000    0.000 utils.py:1501(__setitem__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:349(__subclasshook__)
#         4    0.000    0.000    0.000    0.000 slicing.py:1190(__eq__)
#         1    0.000    0.000    0.000    0.000 itertoolz.py:370(first)
#         1    0.000    0.000    0.000    0.000 blockwise.py:558(<setcomp>)
#         6    0.000    0.000    0.000    0.000 core.py:121(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:697(normalize_object)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         1    0.000    0.000    0.003    0.003 base.py:235(<listcomp>)
#         1    0.000    0.000    0.000    0.000 core.py:1106(numblocks)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.060    0.060 utils.py:805(str_graph)
#         4    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#         3    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 weakref.py:142(__len__)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 base.py:36(is_dask_collection)
#         3    0.000    0.000    0.000    0.000 core.py:1171(_get_chunks)
#         3    0.000    0.000    0.000    0.000 highlevelgraph.py:74(__init__)
#         3    0.000    0.000    0.000    0.000 utils.py:382(__init__)
#         1    0.000    0.000    0.000    0.000 variable.py:145(_maybe_wrap_data)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:492(_get_charset_prefix)
#         8    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 base.py:436(<listcomp>)
#         1    0.000    0.000    0.000    0.000 functools.py:63(wraps)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:76(__init__)
#         1    0.000    0.000    0.000    0.000 base.py:316(<listcomp>)
#         2    0.000    0.000    0.000    0.000 enum.py:557(__new__)
#         1    0.000    0.000    0.000    0.000 core.py:446(__init__)
#         2    0.000    0.000    0.000    0.000 base.py:237(<genexpr>)
#         2    0.000    0.000    0.000    0.000 sre_compile.py:595(isstring)
#         1    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#         1    0.000    0.000    0.003    0.003 base.py:212(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 sre_compile.py:453(_get_iscased)
#         2    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 sre_parse.py:921(fix_flags)
#         1    0.000    0.000    0.000    0.000 dicttoolz.py:10(_get_factory)
#         1    0.000    0.000    0.000    0.000 worker.py:3042(<genexpr>)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:698(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_md5}
#         3    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 types.py:171(__get__)
#         4    0.000    0.000    0.000    0.000 highlevelgraph.py:82(dicts)
#         2    0.000    0.000    0.000    0.000 core.py:1067(__dask_graph__)
#         1    0.000    0.000    0.000    0.000 context.py:59(__get__)
#         2    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         1    0.000    0.000    0.000    0.000 __init__.py:1004(__setitem__)
#         2    0.000    0.000    0.000    0.000 utils_perf.py:126(running_fraction)
#         1    0.000    0.000    0.000    0.000 serialize.py:314(__init__)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:111(__init__)
#         2    0.000    0.000    0.000    0.000 sre_parse.py:81(groups)
#         1    0.000    0.000    0.000    0.000 core.py:1092(__dask_tokenize__)
#         1    0.000    0.000    0.000    0.000 optimization.py:526(<setcomp>)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         1    0.000    0.000    0.000    0.000 core.py:4371(dtype)
#         1    0.000    0.000    0.000    0.000 base.py:234(<listcomp>)
#         1    0.000    0.000    0.000    0.000 core.py:115(<listcomp>)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:286(tell)
#         1    0.000    0.000    0.000    0.000 base.py:200(optimization_function)
#         2    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 core.py:1324(name)
#         1    0.000    0.000    0.000    0.000 weakref.py:128(__getitem__)
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 core.py:1100(__dask_postcompute__)
#         4    0.000    0.000    0.000    0.000 variable.py:2100(load)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:160(__len__)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.getitem}
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:487(getmro)
#         1    0.000    0.000    0.000    0.000 re.py:248(compile)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 __init__.py:997(__len__)
#         1    0.000    0.000    0.000    0.000 client.py:735(asynchronous)
#         3    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 enum.py:659(value)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:249(match)
#         2    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 itertoolz.py:99(<lambda>)
#         1    0.000    0.000    0.000    0.000 core.py:455(__call__)
#         3    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 client.py:2503(<setcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:648(is_closed)
#         1    0.000    0.000    0.000    0.000 weakref.py:119(_commit_removals)
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
